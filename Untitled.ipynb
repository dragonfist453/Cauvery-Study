# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("/home/karthik/Cauvery Study/dataset-whole-rainfall-modified.xlsx")

# %%
X = data.iloc[:,9].values

# %%
y = data.iloc[:,10].values

# %%
plt.scatter(X,y);
plt.xlabel("Groundwater depth - Last 5 years")
plt.ylabel("Groundwarer depth - Last 10 years")
plt.plot()
# Out:
# []

# %%
y1 = data.iloc[:,8].values

# %%
plt.scatter(X,y1);
plt.xlabel("Groundwater depth - Last 5 years")
plt.ylabel("Total rainfall 2018")
plt.plot()
# Out:
# []
